# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('titanic.csv')

# %%
df.head(2)
# Out:
#   Cabin     Ticket number  Survived
# 0   NaN  A/5 21171      5         0
# 1   C85   PC 17599      3         1

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig=df['number'].value_counts().plot.bar()
fig.set_title('passengers travelling with')
# Out:
# Text(0.5, 1.0, 'passengers travelling with')

# %%
# extrct numerical part
df["number_numerical"]=pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN

# %%
df['number_categorical']=np.where(df['number_numerical'].isnull(),df['number'],np.nan)

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                  A

# %%
df['cabin_num']=df['Cabin'].str.extract('(\d+)')# caputre a numerical part
df['cabin_cat']=df['Cabin'].str[0] # captures the first letter

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical cabin_num cabin_cat
# 0                NaN       NaN       NaN
# 1                NaN        85         C
# 2                NaN       NaN       NaN
# 3                NaN       123         C
# 4                  A       NaN       NaN

# %%
df['cabin_cat'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='cabin_cat'>

# %%
# !git init
# !git remote add origin https://github.com/komalrani2404/Learn_ML
# !git add Mixed_data.ipynb

# !git commit -m "El"
# !git branch -M main
# !git push -u origin main
