# %% [markdown]
# # feature engineering

# %% [markdown]
# ### is the process of using domain knowledge to extract features from raw data.
# ### and  improve the performance of ML algo

# %% [markdown]
# ## a) feature transformation

# %% [markdown]
# #### 1 missing value imputation
# #### 2 handling categorical values
# #### 3 outlier detection
# #### 4 Feature scaling

# %% [markdown]
# ## b) feature construction

# %% [markdown]
# ## c) feature Selection

# %% [markdown]
# ## d) feature extraction

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/HP/ml/.git/

# %%
# !git remote add origin https://github.com/komalrani2404/Learn_ML
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/komalrani2404/Learn_ML (fetch)
# origin	https://github.com/komalrani2404/Learn_ML (push)
